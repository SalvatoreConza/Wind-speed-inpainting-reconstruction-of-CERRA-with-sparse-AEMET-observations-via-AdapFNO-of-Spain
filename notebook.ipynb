# %%
# !python compute_stats.py
# Out:
# Loading training data from ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/train_data_m_s_2010_2019_pen_CERRA.nc...
# Computing statistics (this may take a moment)...
# Statistics saved to data/stats.npz
# Mean: [4.5021224], Std: [2.984065]

# %%
# !python train.py --config config.yaml
# Out:
# Using device: cuda
# Loading config from: config.yaml
# Initializing Training Dataset...
# Loading GT: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/train_data_m_s_2010_2019_pen_CERRA.nc
# Loading Mask: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/2010-2019/AEMET/mask_aemet_daily-wind_m_s_2010-2019_CERRA.nc
# Loading normalization stats from: data/stats.npz
# Initializing Validation Dataset...
# Loading GT: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/val_data_m_s_2020_2020_pen_CERRA.nc
# Loading Mask: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/2020-2020/AEMET/mask_aemet_daily-wind_m_s_2020-2020_CERRA.nc
# Loading normalization stats from: data/stats.npz
# --> DETECTED DATA RESOLUTION: 250x250
# Initializing AdaptFNOInpainting Model...
# ...

# %%
# !python inference.py
# Out:
# Loading config from config.yaml...
# Initializing Model...
# Loading checkpoint from checkpoints/best_model.pth...
# Loading stats from data/stats.npz...
# /workspace/AdaptFNO/inference.py:66: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   train_mean = float(stats['mean'])
# /workspace/AdaptFNO/inference.py:67: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   train_std = float(stats['std'])
# Loading test sample from: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/test_data_m_s_2021_2022_pen_CERRA.nc
# Running inference...
# Saved visualization to inference_result.png

# %%
# !python train.py --config config.yaml
# Out:
# Using device: cuda
# Loading config from: config.yaml
# Initializing Training Dataset...
# Loading GT: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/train_data_m_s_2010_2019_pen_CERRA.nc
# Loading Mask: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/2010-2019/AEMET/mask_aemet_daily-wind_m_s_2010-2019_CERRA.nc
# Loading normalization stats from: data/stats.npz
# Initializing Validation Dataset...
# Loading GT: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/val_data_m_s_2020_2020_pen_CERRA.nc
# Loading Mask: ../5.-Data_Split_train_val_test/CERRA/Split_data_2010-2022/ByYear/2020-2020/AEMET/mask_aemet_daily-wind_m_s_2020-2020_CERRA.nc
# Loading normalization stats from: data/stats.npz
# --> DETECTED DATA RESOLUTION: 250x250
# Initializing AdaptFNOInpainting Model...
# ...
